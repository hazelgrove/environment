# %%
from matplotlib import pyplot as plt 
import seaborn as sns

# %%
chat_accs = [0.125,0.02734375, 0.01]
codex_accs = [0.07692307692307693,0.023, 0.02]

num_vars = list(range(1,len( chat_accs)+1))

# %%
plt.plot(num_vars,chat_accs)
plt.title('chat gpt 3.5 accuracy vs number of variables')
plt.xlabel('numer of variables')
plt.ylabel('accuracy')
plt.show()
